# %%
import pandas as pd

# %%
df = pd.read_csv('/home/wngauv/Downloads/order_data.csv')

# %%
df
# Out:
#      Unnamed: 0  order_id client_first_name client_last_name  \
# 0             0       808          Herminia         Cottrell
# 1             1       554             David         Wrassell
# 2             2       439             Hubie      Boulstridge
# 3             3       157              Waly           Evered
# 4             4       194            Livvyy         Swainger
# ..          ...       ...               ...              ...
# 554         554       476            Leanor           Faulks
# 555         555       495           Glendon          Chaffin
# 556         556        52             Lemmy        McCorkell
# 557         557       304             Heida          Ronayne
# 558         558       190             Herta           Cosans
#
#                     client_email client_gender client_birthdate  \
# 0     hcottrellmf@bravesites.com        Female       07/03/2011
# 1          dwrassellfd@nymag.com          Male       05/03/1992
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.to_csv('/home/wngauv/PycharmProjects/happytal_test/order_data.csv', index=False)

# %%
df.loc[df.isnull().any(axis=1)]
# Out:
#      Unnamed: 0  order_id client_first_name client_last_name  \
# 0             0       808          Herminia         Cottrell
# 4             4       194            Livvyy         Swainger
# 5             5       663             Goran           Groger
# 13           13       303            Sterne             Virr
# 15           15       511              Cloe            Dukes
# ..          ...       ...               ...              ...
# 541         541       405             Tedie      Capnerhurst
# 550         550       887         Cleopatra       Oughtright
# 551         551       996           Gerhard           Sember
# 552         552       909            Kenyon         Compford
# 556         556        52             Lemmy        McCorkell
#
#                    client_email client_gender client_birthdate  \
# 0    hcottrellmf@bravesites.com        Female       07/03/2011
# 4      lswainger5d@linkedin.com        Female       17/05/1971
# ...

# %%
df['functional_unit_id'].value_counts()
# Out:
# 3     79
# 5     62
# 4     61
# 9     58
# 7     54
# 1     54
# 10    53
# 8     53
# 2     43
# 6     42
# Name: functional_unit_id, dtype: int64
